# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

os.environ["KHISTO_BIN_DIR"] = (
    "/home/elouen/python/khisto-python/src/khiops/build/linux-gcc-debug/bin/khisto"
)
from khisto.core import compute_histogram

# %%
import random

x = [random.gauss(0, 1) for _ in range(1000)]

# %%
import pyarrow as pa

x = pa.array(x)
compute_histogram(x)
# Out:
# pyarrow.Table
# lower_bound: double
# upper_bound: double
# length: double
# frequency: int64
# probability: double
# density: double
# granularity: int32
# is_best: bool
# ----
# lower_bound: [[-3.03125,-2,-1.5,-1,0,0.5,1,1.5,2,2.5],[-3.03125,-2.34375,-1.5625,-1.09375,-0.625,0.59375,1.15625,2.15625],...,[-3.03125,-2,2],[-3.03125,-2,-1,1,2,3]]
# upper_bound: [[-2,-1.5,-1,0,0.5,1,1.5,2,2.5,3.59375],[-2.34375,-1.5625,-1.09375,-0.625,0.59375,1.15625,2.15625,3.59375],...,[-2,2,3.59375],[-2,-1,1,2,3,3.59375]]
# length: [[1.03125,0.5,0.5,1,0.5,0.5,0.5,0.5,0.5,1.09375],[0.6875,0.78125,0.46875,0.46875,1.21875,0.5625,1,1.4375],...,[1.03125,4,1.59375],[1.03125,1,2,1,1,0.59375]]
# frequency: [[17,37,89,329,215,149,87,51,19,7],[6,37,68,134,487,143,111,14],...,[17,957,26],[17,126,693,138,24,2]]
# probability: [[0.017,0.037,0.089,0.329,0.215,0.149,0.087,0.051,0.019,0.007],[0.006,0.037,0.068,0.134,0.487,0.143,0.111,0.014],...,[0.017,0.957,0.026],[0.017,0.126,0.693,0.138,0.024,0.002]]
# density: [[0.01648484848,0.074,0.178,0.329,0.43,0.298,0.174,0.102,0.038,0.0064],[0.008727272727,0.04736,0.1450666667,0.2858666667,0.3995897436,0.2542222222,0.111,0.009739130435],...,[0.01648484848,0.23925,0.01631372549],[0.01648484848,0.126,0.3465,0.138,0.024,0.003368421053]]
# granularity: [[3,3,3,3,3,3,3,3,3,3],[7,7,7,7,7,7,7,7],...,[1,1,1],[2,2,2,2,2,2]]
# is_best: [[false,false,false,false,false,...,false,false,false,false,false]]

# %%
x = pa.array(["a", "b", "a", "c", "b", "a"])
compute_histogram(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 x = pa.array(["a", "b", "a", "c", "b", "a"])
# ----> 2 compute_histogram(x)
#
# File ~/python/khisto-python/src/khisto/core/cli_adapter.py:205, in compute_histogram(x, granularity)
#     203 # Create temporary input file with array values
#     204 if not pa.types.is_floating(x.type) and not pa.types.is_integer(x.type):
# --> 205     raise TypeError(f"Array must be numeric, got {x.type}")
#     206 with tempfile.NamedTemporaryFile(mode="w", suffix=".txt", delete=False) as temp_input:
#     207     csv.write_csv(
#     208         pa.Table.from_arrays([x], names=["value"]),
#     209         temp_input.name,
#     210         write_options=csv.WriteOptions(include_header=False),
#     211     )
#
# TypeError: Array must be numeric, got string
